# %%
import sys
sys.path.append("../src")

from fpl.extras.datasets.lp_dataset import PydanticDataset
import pandas as pd

# %%
dataset = PydanticDataset(filepath="../data/optimization/lp_data.json")
lp_data = dataset.load()
lp_data
# Out:
# LpData(merged_data=             web_name                            full_name             team  \
# 351           Haaland                       Erling Haaland  Manchester City
# 345         De Bruyne                      Kevin De Bruyne  Manchester City
# 328           M.Salah                        Mohamed Salah        Liverpool
# 317          Diogo J.              Diogo Teixeira da Silva        Liverpool
# 339            Virgil                      Virgil van Dijk        Liverpool
# 327         Luis Díaz                            Luis Díaz        Liverpool
# 350          Gvardiol                       Joško Gvardiol  Manchester City
# 335         Robertson                     Andrew Robertson        Liverpool
# 361             Rúben                Rúben Gato Alves Dias  Manchester City
# 340            Akanji                        Manuel Akanji  Manchester City
# 342          Bernardo   Bernardo Veiga de Carvalho e Silva  Manchester City
# ...

# %%
lp_data.merged_data.sell_price.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 655 entries, 351 to 655
# Series name: sell_price
# Non-Null Count  Dtype
# --------------  -----
# 655 non-null    int64
# dtypes: int64(1)
# memory usage: 10.2 KB

# %%
pd.set_option('display.max_rows', None)

merged_data = lp_data.merged_data
# merged_data.query("web_name == 'Quansah'")
merged_data.query("position == 'GKP'")
# Out:
#           web_name                         full_name             team  \
# 347     Ederson M.         Ederson Santana de Moraes  Manchester City
# 310       A.Becker             Alisson Ramses Becker        Liverpool
# 15            Raya                 David Raya Martin          Arsenal
# 47        Martinez          Emiliano Martínez Romero      Aston Villa
# 152   Arrizabalaga                 Kepa Arrizabalaga      Bournemouth
# 185        Sánchez                    Robert Sánchez          Chelsea
# 235       Pickford                   Jordan Pickford          Everton
# 146     Verbruggen                   Bart Verbruggen         Brighton
# 201      Henderson                    Dean Henderson   Crystal Palace
# 508        Vicario                 Guglielmo Vicario        Tottenham
# 413           Pope                         Nick Pope    Newcastle Utd
# 91         Flekken                      Mark Flekken        Brentford
# ...
