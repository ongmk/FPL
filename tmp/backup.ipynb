# %%
import pandas as pd

# %%
df = pd.read_csv("data/fpl_history_backup.csv")
df.head()
# Out:
# C:\Users\ongmi\AppData\Local\Temp\ipykernel_17692\2805384843.py:1: DtypeWarning: Columns (4,5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/fpl_history_backup.csv")
#       season  round  element                full_name           team position  \
# 0  2023-2024   29.0       21     Albert Sambi Lokonga          Luton      MID
# 1  2023-2024   29.0       23      Nuno Varela Tavares  Nott'm Forest      DEF
# 2  2023-2024   29.0       28              Matt Turner  Nott'm Forest      GKP
# 3  2023-2024   29.0       32  Alexandre Moreno Lopera    Aston Villa      DEF
# 4  2023-2024   29.0       34              Leon Bailey    Aston Villa      MID
#
#    fixture  opponent_team opponent_team_name  total_points  ...  ict_index  \
# 0      287             16      Nott'm Forest           0.0  ...        0.0
# 1      287             12              Luton           0.0  ...        0.0
# ...

# %%
# df = df.drop(["level_0", "index"], axis=1)
# df.to_csv("data/fpl_history_backup.csv", index=False)

# %%
df.tail()
# Out:
#            season  round  element               full_name team position  \
# 188235  2016-2017    1.0      520            Lynden Gooch  NaN      NaN
# 188236  2016-2017    1.0      521              Joel Asoro  NaN      NaN
# 188237  2016-2017    1.0      522           Alex Baptiste  NaN      NaN
# 188238  2016-2017    1.0      523  Trent Alexander-Arnold  NaN      NaN
# 188239  2016-2017    1.0      524     Alexander Manninger  NaN      NaN
#
#         fixture  opponent_team opponent_team_name  total_points  ...  \
# 188235        5             10                NaN           1.0  ...
# 188236        5             10                NaN           0.0  ...
# 188237        6             14                NaN           0.0  ...
# 188238        8              1                NaN           0.0  ...
# 188239        8              1                NaN           0.0  ...
#
#         ict_index value  transfers_balance  selected  transfers_in  \
# ...
